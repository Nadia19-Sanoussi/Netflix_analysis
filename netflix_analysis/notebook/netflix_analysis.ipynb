# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1-CHARGEMENT DU DATASET

# %%
df=pd.read_csv('netflix_titles.csv', encoding="latin1") #pour charger mon datset et le encoding=latin1 c'est parce que les donnees etait encoder

# %% [markdown]
# ## 2- DECOUVERTE DU DATASET

# %%
df.head() #pour afficher les 5 premiere lignes
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# ...

# %%
df.tail(10) #pour afficher les 10 dernieres lignes
# Out:
#      show_id     type               title         director  \
# 8799   s8800    Movie               Zenda   Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8801   s8802    Movie             Zinzana  Majid Al Ansari
# 8802   s8803    Movie              Zodiac    David Fincher
# 8803   s8804  TV Show         Zombie Dumb              NaN
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
# 8807   s8808  TV Show  Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie              Serena     Susanne Bier
#
#                                                    cast  \
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# ...

# %%
df.info() #pour avoir le type de donnees de sa table et aussi le nombre par colonne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8805 non-null   object
#  9   duration      8806 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   0 non-null      float64
#  14  Unnamed: 14   0 non-null      float64
#  15  Unnamed: 15   0 non-null      float64
#  16  Unnamed: 16   0 non-null      float64
#  17  Unnamed: 17   0 non-null      float64
# ...

# %% [markdown]
# ## 3- NETTOYAGE DES DONNEES

# %%
df=df.drop(df.columns[12:26],axis=1) #pour supprimer les colonnes inutile a partir de leur indexe

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isna().sum() #pour connaitre le nombre de valeur manqunte dans sa table par colonne
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isna().mean()*100 #pour voir le pourcentage de valeur manquqnte dans sa tables
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.901237
# cast             9.365422
# country          9.433534
# date_added       0.113520
# release_year     0.000000
# rating           0.045408
# duration         0.034056
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop(["director","cast"], axis=1) #pour supprimer les colonne director et cast que j'ai juger inutile

# %%
df
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands            NaN
# 3         s4  TV Show  Jailbirds New Orleans            NaN
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea
# 8808   s8809    Movie                 Serena  United States
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df[df["country"].isna()] #TO ONLY SHOW ROWS OF MISSING VALUES FOR COUNTRY
# Out:
#      show_id     type                                title country  \
# 2         s3  TV Show                            Ganglands     NaN
# 3         s4  TV Show                Jailbirds New Orleans     NaN
# 5         s6  TV Show                        Midnight Mass     NaN
# 6         s7    Movie     My Little Pony: A New Generation     NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia     NaN
# ...      ...      ...                                  ...     ...
# 8718   s8719    Movie               Westside vs. the World     NaN
# 8759   s8760    Movie               World's Weirdest Homes     NaN
# 8783   s8784  TV Show                                 Yoko     NaN
# 8785   s8786  TV Show                                  YOM     NaN
# 8803   s8804  TV Show                          Zombie Dumb     NaN
#
#               date_added  release_year rating   duration  \
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df.loc[2,"country"]="France"   #TO REPLACE VALUES LINE BY LINE
df.loc[3,"country"]="United States"
df.loc[5,"country"]="United States"
df.loc[6,"country"]="United States"
df.loc[10,"country"]="United Kingdom"
df.loc[8718,"country"]="United States"
df.loc[8760,"country"]="United States"
df.loc[8784,"country"]="United Kingdom"
df.loc[8786,"country"]="India"
df.loc[8803,"country"]="South Korea"
df
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands         France
# 3         s4  TV Show  Jailbirds New Orleans  United States
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea
# 8808   s8809    Movie                 Serena  United States
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df[df["country"].isna()] #to show rows with missing values of the column country
# Out:
#      show_id     type                                              title  \
# 11       s12  TV Show                                   Bangkok Breaking
# 13       s14    Movie                   Confessions of an Invisible Girl
# 14       s15  TV Show                    Crime Stories: India Detectives
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 18       s19    Movie                                          Intrusion
# ...      ...      ...                                                ...
# 8679   s8680  TV Show                                 ViR: The Robot Boy
# 8690   s8691  TV Show                                            Wake Up
# 8759   s8760    Movie                             World's Weirdest Homes
# 8783   s8784  TV Show                                               Yoko
# 8785   s8786  TV Show                                                YOM
#
#      country          date_added  release_year rating   duration  \
# ...

# %%
df.loc[11,"country"]="Thailand" #to replace line by line 
df.loc[13,"country"]="Brazil"
df.loc[16,"country"]="Germany"
df.loc[18,"country"]="United States"
df.loc[8679,"country"]="India"
df.loc[8690,"country"]="United States"
df.drop([8759,8783,8785],axis=0)
df
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands         France
# 3         s4  TV Show  Jailbirds New Orleans  United States
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea
# 8808   s8809    Movie                 Serena  United States
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df[df["country"].isna()]
# Out:
#      show_id     type                                            title  \
# 14       s15  TV Show                  Crime Stories: India Detectives
# 19       s20  TV Show                                           Jaguar
# 20       s21  TV Show  Monsters Inside: The 24 Faces of Billy Milligan
# 22       s23    Movie                                  Avvai Shanmughi
# 23       s24    Movie     Go! Go! Cory Carson: Chrissy Takes the Wheel
# ...      ...      ...                                              ...
# 8609   s8610  TV Show                                           Towies
# 8622   s8623    Movie                           Tremors 2: Aftershocks
# 8759   s8760    Movie                           World's Weirdest Homes
# 8783   s8784  TV Show                                             Yoko
# 8785   s8786  TV Show                                              YOM
#
#      country          date_added  release_year rating  duration  \
# ...

# %%
df=df.dropna(subset=["country"])

# %%
df["country"].isna().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands         France
# 3         s4  TV Show  Jailbirds New Orleans  United States
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea
# 8808   s8809    Movie                 Serena  United States
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df.isna().sum() #pour connaitre le nombre de valeur manquante par coloone
# Out:
# show_id         0
# type            0
# title           0
# country         0
# date_added      9
# release_year    0
# rating          3
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df=df.dropna(subset=["date_added","rating","duration"]) #pour supprimer ls lignes contenant des valeurs manquante des colonnes suivantes 
df
# Out:
#      show_id     type                  title        country  \
# 0         s1    Movie   Dick Johnson Is Dead  United States
# 1         s2  TV Show          Blood & Water   South Africa
# 2         s3  TV Show              Ganglands         France
# 3         s4  TV Show  Jailbirds New Orleans  United States
# 4         s5  TV Show           Kota Factory          India
# ...      ...      ...                    ...            ...
# 8804   s8805    Movie             Zombieland  United States
# 8805   s8806    Movie                   Zoom  United States
# 8806   s8807    Movie                 Zubaan          India
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea
# 8808   s8809    Movie                 Serena  United States
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df.isna().sum()#pour verifer si il reste plus de valeur manquqnte
# Out:
# show_id         0
# type            0
# title           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## 4- CHANGER LE TYPE DES DONNEES DE CERTAINS COLONNES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7976 entries, 0 to 8808
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7976 non-null   object
#  1   type          7976 non-null   object
#  2   title         7976 non-null   object
#  3   country       7976 non-null   object
#  4   date_added    7976 non-null   object
#  5   release_year  7976 non-null   int64
#  6   rating        7976 non-null   object
#  7   duration      7976 non-null   object
#  8   listed_in     7976 non-null   object
#  9   description   7976 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 685.4+ KB

# %%
df = df.copy()
df["date_added"] = pd.to_datetime(df["date_added"], errors="coerce")

# %%
df.info()  #pour verifier si le type de la colonne date_added a bien ete convertit
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7976 entries, 0 to 8808
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7976 non-null   object
#  1   type          7976 non-null   object
#  2   title         7976 non-null   object
#  3   country       7976 non-null   object
#  4   date_added    7891 non-null   datetime64[ns]
#  5   release_year  7976 non-null   int64
#  6   rating        7976 non-null   object
#  7   duration      7976 non-null   object
#  8   listed_in     7976 non-null   object
#  9   description   7976 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 685.4+ KB

# %%
df["year_added"] = df["date_added"].dt.year
df["month_added"] = df["date_added"].dt.month
df["day_added"] = df["date_added"].dt.day
df
# Out:
#      show_id     type                  title        country date_added  \
# 0         s1    Movie   Dick Johnson Is Dead  United States 2021-09-25
# 1         s2  TV Show          Blood & Water   South Africa 2021-09-24
# 2         s3  TV Show              Ganglands         France 2021-09-24
# 3         s4  TV Show  Jailbirds New Orleans  United States 2021-09-24
# 4         s5  TV Show           Kota Factory          India 2021-09-24
# ...      ...      ...                    ...            ...        ...
# 8804   s8805    Movie             Zombieland  United States 2019-11-01
# 8805   s8806    Movie                   Zoom  United States 2020-01-11
# 8806   s8807    Movie                 Zubaan          India 2019-03-02
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea 2024-04-05
# 8808   s8809    Movie                 Serena  United States 2024-04-05
#
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# ...

# %%
df["genre"] = df["listed_in"].str.split(",").str[0].str.strip() #pour avoir le genre des films et series
df
# Out:
#      show_id     type                  title        country date_added  \
# 0         s1    Movie   Dick Johnson Is Dead  United States 2021-09-25
# 1         s2  TV Show          Blood & Water   South Africa 2021-09-24
# 2         s3  TV Show              Ganglands         France 2021-09-24
# 3         s4  TV Show  Jailbirds New Orleans  United States 2021-09-24
# 4         s5  TV Show           Kota Factory          India 2021-09-24
# ...      ...      ...                    ...            ...        ...
# 8804   s8805    Movie             Zombieland  United States 2019-11-01
# 8805   s8806    Movie                   Zoom  United States 2020-01-11
# 8806   s8807    Movie                 Zubaan          India 2019-03-02
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea 2024-04-05
# 8808   s8809    Movie                 Serena  United States 2024-04-05
#
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# ...

# %%
df=df.drop(["listed_in","description"],axis=1)

# %%
df
# Out:
#      show_id     type                  title        country date_added  \
# 0         s1    Movie   Dick Johnson Is Dead  United States 2021-09-25
# 1         s2  TV Show          Blood & Water   South Africa 2021-09-24
# 2         s3  TV Show              Ganglands         France 2021-09-24
# 3         s4  TV Show  Jailbirds New Orleans  United States 2021-09-24
# 4         s5  TV Show           Kota Factory          India 2021-09-24
# ...      ...      ...                    ...            ...        ...
# 8804   s8805    Movie             Zombieland  United States 2019-11-01
# 8805   s8806    Movie                   Zoom  United States 2020-01-11
# 8806   s8807    Movie                 Zubaan          India 2019-03-02
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea 2024-04-05
# 8808   s8809    Movie                 Serena  United States 2024-04-05
#
#       release_year rating   duration  year_added  month_added  day_added  \
# ...

# %% [markdown]
# ### 5-ANALYSE DE DONNEES ET VISUALISATION

# %% [markdown]
# ### 5-1 ANALYSE STATISTIQUE

# %%
df.describe().transpose()  #pour avoir vue generale de ma table et connaitre l'individu moyen
# Out:
#                count                           mean                  min  \
# date_added      7891  2019-04-26 13:09:59.011532032  2008-01-01 00:00:00
# release_year  7976.0                    2013.898696               1942.0
# year_added    7891.0                    2018.817133               2008.0
# month_added   7891.0                       6.637055                  1.0
# day_added     7891.0                      12.328475                  1.0
#
#                               25%                  50%                  75%  \
# date_added    2018-03-30 00:00:00  2019-06-22 00:00:00  2020-07-05 00:00:00
# release_year               2013.0               2017.0               2019.0
# year_added                 2018.0               2019.0               2020.0
# month_added                   4.0                  7.0                 10.0
# day_added                     1.0                 12.0                 20.0
#
#                               max       std
# ...

# %%
df.describe(include="object").transpose()
# Out:
#          count unique            top  freq
# show_id   7976   7976             s1     1
# type      7976      2          Movie  5693
# title     7976   7974         22-Jul     2
# country   7976    747  United States  2816
# rating    7976     15          TV-MA  2937
# duration  7976    212       1 Season  1462
# genre     7976     38         Dramas  1527

# %% [markdown]
# ###  ici on a deja une vue d'ensemble sur les contenus sur netflix:
# -il ya plus de film que de serie (sur 7891 il ya 5693 film)
# - la plus part des contenus sur netflix sont produits en Amerique avec plus de 2782
# - il ya environ 2916 contenu avec une claassification d'age de plus de 18ans
# - le genre le plus represente est le drame dans netflix

# %%
# Top : films vs series
if 'type' in df.columns:
    display(df['type'].value_counts())
# Out:
# type
# Movie      5693
# TV Show    2283
# Name: count, dtype: int64

# %%
#top: genre
if 'genre' in df.columns:
    display(df['genre'].value_counts())
# Out:
# genre
# Dramas                          1527
# Comedies                        1148
# Action & Adventure               817
# Documentaries                    761
# International TV Shows           615
# Children & Family Movies         502
# Crime TV Shows                   361
# Kids' TV                         318
# Stand-Up Comedy                  303
# Horror Movies                    262
# British TV Shows                 236
# Docuseries                       175
# Anime Series                     152
# TV Comedies                      117
# International Movies             114
# Reality TV                        99
# Classic Movies                    80
# TV Dramas                         66
# Thrillers                         63
# TV Action & Adventure             38
# Romantic TV Shows                 32
# Stand-Up Comedy & Talk Shows      31
# Movies                            31
# Independent Movies                20
# Anime Features                    19
# ...

# %%
# Compter les occurrences des genres
top_genres = df["genre"].value_counts().head(15)

# Tracer le bar chart
plt.figure(figsize=(10,6))
top_genres.plot(kind="bar")
plt.title("Top 15 genres sur Netflix")
plt.ylabel("Nombre de titres")
plt.xlabel("Genres")
plt.xticks(rotation=45)
plt.show()

# %%
year_counts = df['release_year'].value_counts().sort_index()
threshold = 10
years_small = year_counts[year_counts < threshold].index
df['year_hybrid'] = df['release_year'].apply(lambda x: 'Other' if x in years_small else x)
df
# Out:
#      show_id     type                  title        country date_added  \
# 0         s1    Movie   Dick Johnson Is Dead  United States 2021-09-25
# 1         s2  TV Show          Blood & Water   South Africa 2021-09-24
# 2         s3  TV Show              Ganglands         France 2021-09-24
# 3         s4  TV Show  Jailbirds New Orleans  United States 2021-09-24
# 4         s5  TV Show           Kota Factory          India 2021-09-24
# ...      ...      ...                    ...            ...        ...
# 8804   s8805    Movie             Zombieland  United States 2019-11-01
# 8805   s8806    Movie                   Zoom  United States 2020-01-11
# 8806   s8807    Movie                 Zubaan          India 2019-03-02
# 8807   s8808  TV Show     Parasyte: The Grey    South Korea 2024-04-05
# 8808   s8809    Movie                 Serena  United States 2024-04-05
#
#       release_year rating   duration  year_added  month_added  day_added  \
# ...

# %%
# Count titles per year
year_counts = df['release_year'].value_counts().sort_index()

# Threshold for grouping
threshold = 50
years_small = year_counts[year_counts < threshold].index

# Replace small years by 'Other'
df['year_hybrid'] = df['release_year'].apply(lambda x: 'Other' if x in years_small else x)

# Order for plotting: numbers first, then 'Other'
years_order = sorted([y for y in df['year_hybrid'].unique() if y != 'Other']) + ['Other']

# Plot
plt.figure(figsize=(14,5))
sns.countplot(x='year_hybrid', data=df, order=years_order)
plt.xticks(rotation=90)
plt.title("Nombre de films/séries par année (small years grouped)")
plt.ylabel("Nombre de titres")
plt.xlabel("Année")
plt.show()

# %% [markdown]
# ### si il ya plus de mois de 50 films/serie damns cette annee il sera classer dans les others,
# - et le dagramme montre que la production de film/serie ne fait croitre elle a chute en 2021 a cause du covid-19 mais elle remonte APRES.

# %%
# Evolution des ajouts par année (date_added)
if 'year_added' in df.columns:
    yearly = df.groupby('year_added').size()
    plt.figure(figsize=(10,4))
    yearly.plot(marker='o')
    plt.title("Titres ajoutés sur netflix par année (date_added)")
    plt.ylabel("Nombre")
    plt.show()

# %% [markdown]
# ### il ya de plus en plus de contenu ajouter sur netflix a partir de 2007 le debut de la plateforme de streaming
# - qui est devenu de plus en plus en populaire et a meme commence a produire des films et des serie

# %%
# Top pays
if 'country' in df.columns:
    countries_expl = df.explode('country')
    display(countries_expl['country'].value_counts().head(20))
# Out:
# country
# United States                    2816
# India                             974
# United Kingdom                    419
# Japan                             243
# South Korea                       201
# Canada                            181
# Spain                             145
# France                            125
# Mexico                            110
# Egypt                             106
# Turkey                            105
# Nigeria                            95
# Australia                          85
# Taiwan                             81
# Indonesia                          79
# Brazil                             78
# United Kingdom, United States      75
# Philippines                        75
# United States, Canada              73
# Germany                            68
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
df['country'].value_counts().head(15).plot(kind='bar')
plt.title("Top 15 pays producteurs")
plt.ylabel("Nombre de titres")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# conclusion

# %%
# --- 2. Répartition des ratings ---
plt.figure(figsize=(10,6))
df['rating'].value_counts().head(15).plot(kind='bar')
plt.title("Répartition des ratings (top 15)")
plt.ylabel("Nombre de titres")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# conclusion

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7976 entries, 0 to 8808
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7976 non-null   object
#  1   type          7976 non-null   object
#  2   title         7976 non-null   object
#  3   country       7976 non-null   object
#  4   date_added    7891 non-null   datetime64[ns]
#  5   release_year  7976 non-null   int64
#  6   rating        7976 non-null   object
#  7   duration      7976 non-null   object
#  8   year_added    7891 non-null   float64
#  9   month_added   7891 non-null   float64
#  10  day_added     7891 non-null   float64
#  11  genre         7976 non-null   object
#  12  year_hybrid   7976 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 872.4+ KB

# %%
### 5-2 ANALYSE BIVARIE

# %% [markdown]
#  # 1. Distribution de la durée (films vs séries)

# %%
# Films (minutes)
movies = df[df['type']=="Movie"].copy()
movies['duration_num'] = pd.to_numeric(movies['duration'].str.extract(r'(\d+)')[0], errors='coerce')

plt.figure(figsize=(10,5))
sns.histplot(movies['duration_num'], bins=40, kde=False, color='skyblue')
plt.title("Distribution de la durée des films (minutes)")
plt.xlabel("Durée (minutes)")
plt.ylabel("Nombre de films")
plt.show()

# %% [markdown]
# conclusion:sur netflix la duree des films est en moyenne de 100mins. pourquoi? est ce que la taille d'un film influence les consomateurs

# %%
shows = df[df['type']=="TV Show"].copy()
shows['seasons_num'] = pd.to_numeric(shows['duration'].str.extract(r'(\d+)')[0], errors='coerce')

plt.figure(figsize=(8,4))
shows['seasons_num'].value_counts().sort_index().plot(kind='bar', color='salmon')
plt.title("Distribution du nombre de saisons des séries")
plt.xlabel("Nombre de saisons")
plt.ylabel("Nombre de séries")
plt.show()

# %% [markdown]
# conclusion: on remarque qu'il ya beaucoup de serie a 1 saison. est ce qui marche le mieux? pourquoi cet ecart entre immense ?

# %% [markdown]
# 2. Répartition des ratings

# %%
# Croisement rating vs type
plt.figure(figsize=(12,6))
sns.countplot(data=df, x="rating", hue="type", order=df['rating'].value_counts().index[:10])
plt.title("Rating par type (films vs séries)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# conclusionG → General Audience → Tout public (aucune restriction, adapté aux enfants).
#
# PG → Parental Guidance → Accord parental suggéré (certains passages peuvent ne pas convenir aux enfants).
#
# PG-13 → Parents Strongly Cautioned → Déconseillé aux moins de 13 ans (violence légère, langage...).
#
# R → Restricted → Les moins de 17 ans doivent être accompagnés d’un adulte (violence, langage, sexualité...).
#
# NC-17 → Adults Only → Interdit aux moins de 17 ans (rare, contenu adulte explicite).
#
# 📺 Ratings des séries TV (TV Parental Guidelines)
#
# TV-Y → Convient à tous les enfants.
#
# TV-Y7 → Convient aux enfants de plus de 7 ans.
#
# TV-G → Convient à tous publics.
#
# TV-PG → Accord parental suggéré.
#
# TV-14 → Déconseillé aux moins de 14 ans.
#
# TV-MA → Public adulte, réservé aux +17 ans (violence, sexe, langage).

# %% [markdown]
#  3. Genres par pays (top 5 pays)

# %%
top_countries = df['country'].value_counts().index[:5]
subset = df[df['country'].isin(top_countries)]

plt.figure(figsize=(12,6))
sns.countplot(data=subset, x="country", hue="genre",
              order=top_countries,
              hue_order=subset['genre'].value_counts().index[:6])
plt.title("Genres dominants dans les 5 principaux pays")
plt.legend(title="Genre", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# conclusion:  unitedd states sans grandes surprises est a la tete du classement et produit tout genre surtout ls documentaires qui n'est pas fais beaucoup ailleurs. suivit de l'inde a ma grande surprise le bollywood explose autant que Hollywood.

# %% [markdown]
#  4. Tendance d’ajouts par genre

# %%
year_genre = df.groupby(['year_added','genre']).size().reset_index(name='count')
top_genres = df['genre'].value_counts().index[:5]
subset = year_genre[year_genre['genre'].isin(top_genres)]

plt.figure(figsize=(12,6))
sns.lineplot(data=subset, x="year_added", y="count", hue="genre", marker="o")
plt.title("Évolution des ajouts par genre (top 5)")
plt.ylabel("Nombre de titres")
plt.show()

# %% [markdown]
# conclusion: les films et series drama sont les plus populaires sur le marche donc ona produit plus et y'en a beaucoup plus sur netflix.

# %% [markdown]
# 5. Délai entre sortie et ajout sur Netflix

# %%
df['delay'] = df['year_added'] - df['release_year']
plt.figure(figsize=(10,5))
sns.histplot(df['delay'].dropna(), bins=40, kde=False, color='purple')
plt.title("Délai entre sortie et ajout sur Netflix")
plt.xlabel("Années après sortie")
plt.ylabel("Nombre de titres")
plt.show()

# %% [markdown]
# conclusion: la plupart des contenus sur netflix sont produit par netflix et donc directement ajouter a la plateforme de steaming. et les films et series pas produit par netflix sont ajouter dans 10 annees apres leur production. plus les annees de fin de production augmente moins il a de chance de se trouver sur netflix. Netflix a plus de contenu recent.
